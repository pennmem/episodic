# %%
import graph_CMR2_beta as graph

# %%
graph.main()
# Out:
# Separating by session
# Subject ID is: 93_1
# Subject ID is: 93_10
# Subject ID is: 93_11
# Subject ID is: 93_12
# Subject ID is: 93_13
# Subject ID is: 93_14
# Subject ID is: 93_15
# Subject ID is: 93_16
# Subject ID is: 93_17
# Subject ID is: 93_18
# Subject ID is: 93_19
# Subject ID is: 93_2
# Subject ID is: 93_20
# Subject ID is: 93_21
# Subject ID is: 93_22
# Subject ID is: 93_23
# Subject ID is: 93_24
# Subject ID is: 93_3
# Subject ID is: 93_4
# Subject ID is: 93_5
# Subject ID is: 93_6
# Subject ID is: 93_7
# Subject ID is: 93_8
# Subject ID is: 93_9
# CMR Time: 72.3594210148
# using shais recoding vers
# -1
# lagCRP2.py:174: RuntimeWarning: Mean of empty slice
#   return np.nanmean(crps, axis=0), (np.nanstd(crps, axis=0)
# /home1/ddiwik/anaconda2/envs/shadowfox/lib/python2.7/site-packages/numpy/lib/nanfunctions.py:1423: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# using shais recoding vers

# %%
import sys
import numpy as np
import os
cwd = os.getcwd()
base = os.path.dirname(cwd)
#main_directort = ('/home1/ddiwik/_Central_Command/CMR2/elementary/CMR2_Fast_Jul17_Edits')
main = os.path.join(base, 'CMR2_Fast_Jul17_Edits')
params = np.loadtxt(os.path.join(main, 'xopt_k02.txt'))

# %%
params
# Out:
# array([  0.452439,   0.563569,   0.489512,   0.68386 ,   0.236765,
#          1.408667,   0.456488,   0.399926,   2.454099,   0.360579,
#         12.190979,   0.850908,   0.15951 ,   0.37542 ])
